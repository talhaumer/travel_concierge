# %%
import sys
import os

# Add the parent folder to the Python path
sys.path.append(os.path.abspath(".."))  # adjust ".." if notebook is nested deeper

# Now imports will work
from src.graph import TravelGraph
from src.observability import setup_observability, export_trace, get_metrics
from dotenv import load_dotenv

# %%
# Load environment variables
load_dotenv()
# Out:
# True

# %%
# Setup observability
tracer = setup_observability()

# %%
travel_graph = TravelGraph()

# %%
user_query = "Plan a 3-day trip to Paris from New York, focusing on art and culture with a budget of $2000 for two people.  Include must-see attractions, local dining options, and a mix of guided tours and free exploration."

# %%
print("Testing with query:", user_query)
try:
    result = travel_graph.invoke(user_query)
    print("Success! Result:")
    print(result)
except Exception as e:
    print(f"Error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# Testing with query: Plan a 3-day trip to Paris from New York, focusing on art and culture with a budget of $2000 for two people.  Include must-see attractions, local dining options, and a mix of guided tours and free exploration.
# DEBUG: Searching places with query='tourist attractions', location='Paris', limit=6
# DEBUG: Using fallback data for Paris
# tourist attractions 6 Paris
# Error getting transit info: 401 Client Error: Unauthorized for url: https://transit.land/api/v2/rest/feeds?served_by=paris
# Success! Result:
# ...
